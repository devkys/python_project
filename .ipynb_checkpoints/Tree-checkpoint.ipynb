# %%
from anytree import Node, RenderTree
all_node_set=[]
root = Node("root", data=0)
all_node_set.apped(root)
for i in range(0,3):
    new_node = Node(f'child_{i}', parent = root, data=0)
    root.data+= 1
    all_node_set.append(new_node)
Node("child_child_1", parent=root.children[0], data=0)
print("=="*20)
for row in RenderTree(root):
    pre, fill, node = row
    print(f"{pre}{node.name}, data:{node.data}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4920/1166469962.py in <module>
# ----> 1 from anytree import Node, RenderTree
#       2 all_node_set=[]
#       3 root = Node("root", data=0)
#       4 all_node_set.apped(root)
#       5 for i in range(0,3):
#
# ModuleNotFoundError: No module named 'anytree'
